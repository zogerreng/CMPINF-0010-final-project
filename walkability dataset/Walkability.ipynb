# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

pittmap = gpd.read_file("walkscores/WalkScores.shp")
#hoods = pd.read_csv("walkscores.csv")
pittmap = pittmap.sort_values(by=['Walk_Score'], ascending=False)
#print(pittmap[['NAME','Walk_Score']].head(30))

print(pittmap[['NAME','Walk_Score']].head(30))
# Out:
#      NAME  Walk_Score
# 211   201         100
# 236  4455          97
# 395   603          91
# 386   703          91
# 396   709          89
# 215  2206          89
# 385   605          88
# 387   705          88
# 388   708          88
# 214  1408          88
# 15    807          86
# 64   5627          86
# 329   809          86
# 17   1115          86
# 328   804          86
# 389   902          86
# 390   903          86
# 12   1702          85
# 230  2503          83
# 57   5252          83
# 140  4732          83
# 233   203          83
# 327   802          82
# 326   103          82
# 62   9822          82
# 382   806          82
# 367   404          82
# 187  1403          80
# 225  1413          80
# 68   4722          78

# %%
var = 'Walk_Score'

vmin, vmax = 0, 100

fig, ax = plt.subplots(1, figsize=(20, 12))
ax.axis('off')
ax.set_title('Walkability Scores in Allegheny County', fontdict={'fontsize': '25', 'fontweight' : '3'})

ax.margins(x=-0.3,y=-0.3)

sm = plt.cm.ScalarMappable(cmap='Greens', norm=plt.Normalize(vmin=vmin, vmax=vmax))

cbar = fig.colorbar(sm)

pittmap.plot(column=variable, cmap='Greens', linewidth=0.8, ax=ax, edgecolor='0.8')

pittmap.apply(lambda x: ax.annotate(text=x.NAME, xy=x.geometry.centroid.coords[0], ha='center'),axis=1);
